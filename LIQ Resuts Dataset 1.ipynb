# %% [markdown]
# SOL Datset 1
# The return when buying short liquidations for 1s is:-0.0016200047644407706
# The return when buying short liquidations for 5s is:0.0024448113407553444
# The return when buying short liquidations for 10s is:0.04235879719198881
# The return when buying short liquidations for 30s is:-0.08404062047418145
# The return when buying short liquidations for 60s is:0.061627149836081474
# The return when buying short liquidations for 300s is:0.35845163485076204
# The return when selling long liquidations for 1s is:0.005018026794955392
# The return when selling long liquidations for 5s is:0.04935795910458355
# The return when selling long liquidations for 10s is:0.09395583570262797
# The return when selling long liquidations for 30s is:0.0988698905220943
# The return when selling long liquidations for 60s is:-0.02655704556023185
# The return when selling long liquidations for 300s is:0.12970890550715922
#
# Number of Long Trades:261.0
# Number of Short Trades:-351.0
# Estimated Trading fees for Longs:0.069426
# Estimated Trading fees for Shorts:-0.093366
# The gross return when buying short liquidations for 10s is:0.04235879719198881
# The net return when buying short liquidations for 10s is:-0.02706720280801119
# The gross return when selling long liquidations for 10s is:0.09395583570262797
# The net return when selling long liquidations for 10s is:0.0005898357026279666
# The win percent of longs is: 0.5402298850574713
# The win percent of shorts is: -0.6467236467236467
# The biggest winning trade on the long side is: 0.0033204904230273763
# The biggest losing trade on the long side is: -0.003401320420112148
# The biggest winning trade on the short side is: 0.003232678077584308
# The biggest losing trade on the short side is: -0.002875070273207139

# %% [markdown]
# ADA DS 1
#
# The return when buying short liquidations for 1s is:-0.000448575656343812
# The return when buying short liquidations for 5s is:0.00225514124352386
# The return when buying short liquidations for 10s is:0.007881287064190088
# The return when buying short liquidations for 30s is:0.028255468091460414
# The return when buying short liquidations for 60s is:0.03241799204744492
# The return when buying short liquidations for 300s is:-0.013955552756592026
# The return when selling long liquidations for 1s is:-0.00022869798321587724
# The return when selling long liquidations for 5s is:0.0006661767823753079
# The return when selling long liquidations for 10s is:-0.0008816072407103841
# The return when selling long liquidations for 30s is:-0.003965248381469533
# The return when selling long liquidations for 60s is:-0.011012957848675288
# The return when selling long liquidations for 300s is:-0.04866430611855057
#
# Number of Long Trades:7.0
# Number of Short Trades:-12.0
# Estimated Trading fees for Longs:0.0018620000000000002
# Estimated Trading fees for Shorts:-0.0031920000000000004
# The gross return when buying short liquidations for 10s is:0.007881287064190088
# The net return when buying short liquidations for 10s is:0.006019287064190088
# The gross return when selling long liquidations for 10s is:-0.0008816072407103841
# The net return when selling long liquidations for 10s is:-0.004073607240710385
# The win percent of longs is: 1.0
# The win percent of shorts is: -0.16666666666666666
# The biggest winning trade on the long side is: 0.0018020047302623435
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.0004477779021604791
# The biggest losing trade on the short side is: -0.0004476776720761802

# %% [markdown]
# #BCH ds1
#
# The return when buying short liquidations for 1s is:0.0005644059596250032
# The return when buying short liquidations for 5s is:0.006466630248637494
# The return when buying short liquidations for 10s is:-0.0022047645795728703
# The return when buying short liquidations for 30s is:-0.024765642186454887
# The return when buying short liquidations for 60s is:-0.008353269198174008
# The return when buying short liquidations for 300s is:0.03683444159857329
# The return when selling long liquidations for 1s is:0.0014043367991565807
# The return when selling long liquidations for 5s is:0.005247434384739036
# The return when selling long liquidations for 10s is:0.005894265305158272
# The return when selling long liquidations for 30s is:0.0010644523070437169
# The return when selling long liquidations for 60s is:-0.013996425415189652
# The return when selling long liquidations for 300s is:0.05952503153458692
#
# Number of Long Trades:27.0
# Number of Short Trades:-27.0
# Estimated Trading fees for Longs:0.007182
# Estimated Trading fees for Shorts:-0.007182
# The gross return when buying short liquidations for 10s is:-0.0022047645795728703
# The net return when buying short liquidations for 10s is:-0.009386764579572871
# The gross return when selling long liquidations for 10s is:0.005894265305158272
# The net return when selling long liquidations for 10s is:-0.001287734694841728
# The win percent of longs is: 0.48148148148148145
# The win percent of shorts is: -0.7037037037037037
# The biggest winning trade on the long side is: 0.0020702371068437217
# The biggest losing trade on the long side is: -0.0021005190117364555
# The biggest winning trade on the short side is: 0.0008583424683034198
# The biggest losing trade on the short side is: -0.0006768690575655837

# %% [markdown]
# BNB ds1
#
# The return when buying short liquidations for 1s is:0.0009859477752132977
# The return when buying short liquidations for 5s is:-0.0011538768283080123
# The return when buying short liquidations for 10s is:-0.0031408491087517075
# The return when buying short liquidations for 30s is:0.01001925550469778
# The return when buying short liquidations for 60s is:0.024715840159453405
# The return when buying short liquidations for 300s is:-0.05202785145525241
# The return when selling long liquidations for 1s is:0.002892423202326246
# The return when selling long liquidations for 5s is:0.01246399310528938
# The return when selling long liquidations for 10s is:0.015895476640874366
# The return when selling long liquidations for 30s is:0.0050759807504668925
# The return when selling long liquidations for 60s is:-0.015169721538166564
# The return when selling long liquidations for 300s is:-0.048586170474989324
#
# Number of Long Trades:39.0
# Number of Short Trades:-68.0
# Estimated Trading fees for Longs:0.010374000000000001
# Estimated Trading fees for Shorts:-0.018088
# The gross return when buying short liquidations for 10s is:-0.0031408491087517075
# The net return when buying short liquidations for 10s is:-0.013514849108751708
# The gross return when selling long liquidations for 10s is:0.015895476640874366
# The net return when selling long liquidations for 10s is:-0.002192523359125634
# The win percent of longs is: 0.46153846153846156
# The win percent of shorts is: -0.6911764705882353
# The biggest winning trade on the long side is: 0.0006540161261690963
# The biggest losing trade on the long side is: -0.0011201239603849918
# The biggest winning trade on the short side is: 0.0011467135377992755
# The biggest losing trade on the short side is: -0.0008955975781547042

# %% [markdown]
# BTC ds1
#
# The return when buying short liquidations for 1s is:0.002467961589209935
# The return when buying short liquidations for 5s is:-0.009707396174964848
# The return when buying short liquidations for 10s is:-0.011075442845342613
# The return when buying short liquidations for 30s is:0.004065391158592328
# The return when buying short liquidations for 60s is:-0.0013051574095317084
# The return when buying short liquidations for 300s is:0.26324032271069986
# The return when selling long liquidations for 1s is:-0.005048498582121835
# The return when selling long liquidations for 5s is:-0.005732501787065995
# The return when selling long liquidations for 10s is:-0.017325234528478693
# The return when selling long liquidations for 30s is:-0.017420214301810025
# The return when selling long liquidations for 60s is:-0.01949152101198215
# The return when selling long liquidations for 300s is:0.17908216303853253
#
# Number of Long Trades:400.0
# Number of Short Trades:-499.0
# Estimated Trading fees for Longs:0.10640000000000001
# Estimated Trading fees for Shorts:-0.13273400000000002
# The gross return when buying short liquidations for 10s is:-0.011075442845342613
# The net return when buying short liquidations for 10s is:-0.11747544284534261
# The gross return when selling long liquidations for 10s is:-0.017325234528478693
# The net return when selling long liquidations for 10s is:-0.15005923452847872
# The win percent of longs is: 0.49
# The win percent of shorts is: -0.5470941883767535
# The biggest winning trade on the long side is: 0.0019595971696325675
# The biggest losing trade on the long side is: -0.001439017137171984
# The biggest winning trade on the short side is: 0.00189844566715746
# The biggest losing trade on the short side is: -0.0034240927639172937

# %% [markdown]
# DOGE
#
# The return when buying short liquidations for 1s is:-0.0002953680718542847
# The return when buying short liquidations for 5s is:0.0022903742548550828
# The return when buying short liquidations for 10s is:0.012436414488994827
# The return when buying short liquidations for 30s is:0.01011817887485234
# The return when buying short liquidations for 60s is:0.08031158778283315
# The return when buying short liquidations for 300s is:0.2467310197756396
# The return when selling long liquidations for 1s is:0.0015956933273986434
# The return when selling long liquidations for 5s is:0.00827200142133868
# The return when selling long liquidations for 10s is:0.020134042749771326
# The return when selling long liquidations for 30s is:0.022041769935256326
# The return when selling long liquidations for 60s is:-0.015054455148899259
# The return when selling long liquidations for 300s is:-0.010482273284335493
#
# Number of Long Trades:48.0
# Number of Short Trades:-49.0
# Estimated Trading fees for Longs:0.012768000000000002
# Estimated Trading fees for Shorts:-0.013034
# The gross return when buying short liquidations for 10s is:0.012436414488994827
# The net return when buying short liquidations for 10s is:-0.0003315855110051745
# The gross return when selling long liquidations for 10s is:0.020134042749771326
# The net return when selling long liquidations for 10s is:0.007100042749771326
# The win percent of longs is: 0.625
# The win percent of shorts is: -0.5714285714285714
# The biggest winning trade on the long side is: 0.001628388234895125
# The biggest losing trade on the long side is: -0.0014851644981113098
# The biggest winning trade on the short side is: 0.002191046142777736
# The biggest losing trade on the short side is: -0.0011555869418676435

# %% [markdown]
# DOT
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:0.0021924192597161576
# The return when selling long liquidations for 5s is:0.0071030598592012155
# The return when selling long liquidations for 10s is:0.00920854097124841
# The return when selling long liquidations for 30s is:0.013066329953405164
# The return when selling long liquidations for 60s is:0.023582205459697053
# The return when selling long liquidations for 300s is:-0.0401044783820166
#
# Number of Long Trades:0.0
# Number of Short Trades:-37.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.009842
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:0.00920854097124841
# The net return when selling long liquidations for 10s is:-0.0006334590287515908
# The win percent of longs is: nan
# The win percent of shorts is: -0.6486486486486487
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.0012216538138505012
# The biggest losing trade on the short side is: -0.00015287013681882351

# %% [markdown]
# ETC
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.00039810920869843034
# The return when selling long liquidations for 5s is:-0.00305204061019278
# The return when selling long liquidations for 10s is:-0.008627562491376348
# The return when selling long liquidations for 30s is:-0.005720649285778703
# The return when selling long liquidations for 60s is:-0.0050760298390799445
# The return when selling long liquidations for 300s is:0.0146747339172747
#
# Number of Long Trades:0.0
# Number of Short Trades:-30.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.007980000000000001
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:-0.008627562491376348
# The net return when selling long liquidations for 10s is:-0.01660756249137635
# The win percent of longs is: nan
# The win percent of shorts is: -0.03333333333333333
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.00018937600605999452
# The biggest losing trade on the short side is: -0.0006828916668247694

# %% [markdown]
# ETH
#
# The return when buying short liquidations for 1s is:0.0032062673665279955
# The return when buying short liquidations for 5s is:0.014003598863110422
# The return when buying short liquidations for 10s is:0.02807692675972475
# The return when buying short liquidations for 30s is:0.10082610133651372
# The return when buying short liquidations for 60s is:0.14071998067887764
# The return when buying short liquidations for 300s is:0.2950486739134471
# The return when selling long liquidations for 1s is:0.003939649558481226
# The return when selling long liquidations for 5s is:0.02054688210856764
# The return when selling long liquidations for 10s is:0.024151035967850593
# The return when selling long liquidations for 30s is:0.04772277147728891
# The return when selling long liquidations for 60s is:-0.021469999966264763
# The return when selling long liquidations for 300s is:0.18016348979568753
#
# Number of Long Trades:247.0
# Number of Short Trades:-377.0
# Estimated Trading fees for Longs:0.06570200000000001
# Estimated Trading fees for Shorts:-0.10028200000000001
# The gross return when buying short liquidations for 10s is:0.02807692675972475
# The net return when buying short liquidations for 10s is:-0.03762507324027526
# The gross return when selling long liquidations for 10s is:0.024151035967850593
# The net return when selling long liquidations for 10s is:-0.07613096403214942
# The win percent of longs is: 0.5991902834008097
# The win percent of shorts is: -0.5437665782493368
# The biggest winning trade on the long side is: 0.0020348572704788834
# The biggest losing trade on the long side is: -0.002711840705577996
# The biggest winning trade on the short side is: 0.0017487897690914745
# The biggest losing trade on the short side is: -0.003322596722242116

# %% [markdown]
# FIL
#
# The return when buying short liquidations for 1s is:0.0029751044047440466
# The return when buying short liquidations for 5s is:0.025257370168965905
# The return when buying short liquidations for 10s is:0.035531843953338416
# The return when buying short liquidations for 30s is:0.07260699607794757
# The return when buying short liquidations for 60s is:0.08764316666833684
# The return when buying short liquidations for 300s is:0.13594700322266226
# The return when selling long liquidations for 1s is:-0.002956469740658579
# The return when selling long liquidations for 5s is:-0.026152960062251915
# The return when selling long liquidations for 10s is:-0.03876338336166564
# The return when selling long liquidations for 30s is:-0.005570580232756903
# The return when selling long liquidations for 60s is:-0.014679224749580513
# The return when selling long liquidations for 300s is:-0.01061700525230383
#
# Number of Long Trades:81.0
# Number of Short Trades:-58.0
# Estimated Trading fees for Longs:0.021546000000000003
# Estimated Trading fees for Shorts:-0.015428
# The gross return when buying short liquidations for 10s is:0.035531843953338416
# The net return when buying short liquidations for 10s is:0.013985843953338413
# The gross return when selling long liquidations for 10s is:-0.03876338336166564
# The net return when selling long liquidations for 10s is:-0.05419138336166564
# The win percent of longs is: 0.691358024691358
# The win percent of shorts is: -0.2413793103448276
# The biggest winning trade on the long side is: 0.0020330368487929615
# The biggest losing trade on the long side is: -0.0008728288382649526
# The biggest winning trade on the short side is: 0.0014699877501019932
# The biggest losing trade on the short side is: -0.003416175591425478

# %% [markdown]
# ICP
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:4.104012263326872e-05
# The return when selling long liquidations for 5s is:0.0016162694820484127
# The return when selling long liquidations for 10s is:0.0034405488006802685
# The return when selling long liquidations for 30s is:-0.010198819774154589
# The return when selling long liquidations for 60s is:-0.02068806134963963
# The return when selling long liquidations for 300s is:-0.0035657121148962223
#
# Number of Long Trades:0.0
# Number of Short Trades:-9.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.0023940000000000003
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:0.0034405488006802685
# The net return when selling long liquidations for 10s is:0.0010465488006802682
# The win percent of longs is: nan
# The win percent of shorts is: -1.0
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.0007462377181707695
# The biggest losing trade on the short side is: nan

# %% [markdown]
# LINK
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.0001732872875744953
# The return when selling long liquidations for 5s is:0.001839439927674345
# The return when selling long liquidations for 10s is:0.001011217452991462
# The return when selling long liquidations for 30s is:0.0048899640757194066
# The return when selling long liquidations for 60s is:0.025314603707048296
# The return when selling long liquidations for 300s is:0.07763891693549173
#
# Number of Long Trades:0.0
# Number of Short Trades:-38.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.010108
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:0.001011217452991462
# The net return when selling long liquidations for 10s is:-0.009096782547008539
# The win percent of longs is: nan
# The win percent of shorts is: -0.5526315789473685
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.0008309726156752414
# The biggest losing trade on the short side is: -0.0007425283088917607

# %% [markdown]
# LTC
#
# The return when buying short liquidations for 1s is:0.0012238479179083358
# The return when buying short liquidations for 5s is:0.003491221982405219
# The return when buying short liquidations for 10s is:0.008924464133064105
# The return when buying short liquidations for 30s is:0.010198303524319385
# The return when buying short liquidations for 60s is:0.028505109202992998
# The return when buying short liquidations for 300s is:0.07844080237580045
# The return when selling long liquidations for 1s is:0.001118233358860297
# The return when selling long liquidations for 5s is:0.0059787381919422615
# The return when selling long liquidations for 10s is:0.011475326053791963
# The return when selling long liquidations for 30s is:0.016853889789099668
# The return when selling long liquidations for 60s is:0.015593797696491789
# The return when selling long liquidations for 300s is:0.036993394335361494
#
# Number of Long Trades:20.0
# Number of Short Trades:-11.0
# Estimated Trading fees for Longs:0.00532
# Estimated Trading fees for Shorts:-0.002926
# The gross return when buying short liquidations for 10s is:0.008924464133064105
# The net return when buying short liquidations for 10s is:0.003604464133064105
# The gross return when selling long liquidations for 10s is:0.011475326053791963
# The net return when selling long liquidations for 10s is:0.008549326053791963
# The win percent of longs is: 0.8
# The win percent of shorts is: -0.8181818181818182
# The biggest winning trade on the long side is: 0.0010375462032293403
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.001622464898595887
# The biggest losing trade on the short side is: -0.00025314853490298375

# %% [markdown]
# MATIC
#
# The return when buying short liquidations for 1s is:0.000741192793385873
# The return when buying short liquidations for 5s is:0.00044583948108733106
# The return when buying short liquidations for 10s is:-0.002063748877915336
# The return when buying short liquidations for 30s is:0.011844261575872522
# The return when buying short liquidations for 60s is:0.03332442537491003
# The return when buying short liquidations for 300s is:0.02952618150496257
# The return when selling long liquidations for 1s is:0.0
# The return when selling long liquidations for 5s is:0.0
# The return when selling long liquidations for 10s is:0.0
# The return when selling long liquidations for 30s is:0.0
# The return when selling long liquidations for 60s is:0.0
# The return when selling long liquidations for 300s is:0.0
#
# Number of Long Trades:11.0
# Number of Short Trades:0.0
# Estimated Trading fees for Longs:0.002926
# Estimated Trading fees for Shorts:0.0
# The gross return when buying short liquidations for 10s is:-0.002063748877915336
# The net return when buying short liquidations for 10s is:-0.004989748877915336
# The gross return when selling long liquidations for 10s is:0.0
# The net return when selling long liquidations for 10s is:0.0
# The win percent of longs is: 0.45454545454545453
# The win percent of shorts is: nan
# The biggest winning trade on the long side is: 0.0011044842058757342
# The biggest losing trade on the long side is: -0.0011765570997867827
# The biggest winning trade on the short side is: nan
# The biggest losing trade on the short side is: nan

# %% [markdown]
# Theta
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.0006791245650223614
# The return when selling long liquidations for 5s is:-0.004853843796591232
# The return when selling long liquidations for 10s is:-0.011691978961658273
# The return when selling long liquidations for 30s is:-0.022381349391797374
# The return when selling long liquidations for 60s is:-0.03678940557288207
# The return when selling long liquidations for 300s is:-0.012975247319272012
#
# Number of Long Trades:0.0
# Number of Short Trades:-9.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.0023940000000000003
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:-0.011691978961658273
# The net return when selling long liquidations for 10s is:-0.014085978961658273
# The win percent of longs is: nan
# The win percent of shorts is: -0.0
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: nan
# The biggest losing trade on the short side is: -0.0025136996631641914

# %% [markdown]
# UNI
#
# The return when buying short liquidations for 1s is:0.003968358227969832
# The return when buying short liquidations for 5s is:0.010311486233448503
# The return when buying short liquidations for 10s is:0.01554049681437877
# The return when buying short liquidations for 30s is:0.041299889815958044
# The return when buying short liquidations for 60s is:0.03676171413170461
# The return when buying short liquidations for 300s is:0.08272760062855929
# The return when selling long liquidations for 1s is:0.0019577612888392487
# The return when selling long liquidations for 5s is:0.009577279476167684
# The return when selling long liquidations for 10s is:0.01851386528677865
# The return when selling long liquidations for 30s is:0.01983480998563861
# The return when selling long liquidations for 60s is:0.03726451514349328
# The return when selling long liquidations for 300s is:0.060497904153513825
#
# Number of Long Trades:37.0
# Number of Short Trades:-21.0
# Estimated Trading fees for Longs:0.009842
# Estimated Trading fees for Shorts:-0.005586000000000001
# The gross return when buying short liquidations for 10s is:0.01554049681437877
# The net return when buying short liquidations for 10s is:0.00569849681437877
# The gross return when selling long liquidations for 10s is:0.01851386528677865
# The net return when selling long liquidations for 10s is:0.01292786528677865
# The win percent of longs is: 0.7837837837837838
# The win percent of shorts is: -0.9047619047619048
# The biggest winning trade on the long side is: 0.0015090543259556638
# The biggest losing trade on the long side is: -0.0007113893433876208
# The biggest winning trade on the short side is: 0.0023794527258729735
# The biggest losing trade on the short side is: -0.00013780748294637

# %% [markdown]
# VET
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-6.18536295708734e-05
# The return when selling long liquidations for 5s is:0.000630887128322864
# The return when selling long liquidations for 10s is:0.0012493989399695133
# The return when selling long liquidations for 30s is:0.001249402765604375
# The return when selling long liquidations for 60s is:0.0022390279382802558
# The return when selling long liquidations for 300s is:0.0029688709272659795
#
#
# Number of Long Trades:0.0
# Number of Short Trades:-2.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.000532
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:0.0012493989399695133
# The net return when selling long liquidations for 10s is:0.0007173989399695133
# The win percent of longs is: nan
# The win percent of shorts is: -1.0
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 0.0007174577256590406
# The biggest losing trade on the short side is: nan

# %% [markdown]
# XLM
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.0001833262980380791
# The return when selling long liquidations for 5s is:-0.000733255265546611
# The return when selling long liquidations for 10s is:-0.000733255265546611
# The return when selling long liquidations for 30s is:-0.005681685589889989
# The return when selling long liquidations for 60s is:-0.01638931964332113
# The return when selling long liquidations for 300s is:-0.02127691491353812
#
# Number of Long Trades:0.0
# Number of Short Trades:-18.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.004788000000000001
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:-0.000733255265546611
# The net return when selling long liquidations for 10s is:-0.005521255265546612
# The win percent of longs is: nan
# The win percent of shorts is: -0.05555555555555555
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: 9.121174807311646e-05
# The biggest losing trade on the short side is: -0.00018330965583617732

# %% [markdown]
# XMR
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.0012841689608613532
# The return when selling long liquidations for 5s is:-0.006506767539764891
# The return when selling long liquidations for 10s is:-0.010194457725833633
# The return when selling long liquidations for 30s is:-0.016617595608798247
# The return when selling long liquidations for 60s is:0.006131904235912671
# The return when selling long liquidations for 300s is:-0.011271946218955761
#
# Number of Long Trades:0.0
# Number of Short Trades:-9.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.0023940000000000003
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:-0.010194457725833633
# The net return when selling long liquidations for 10s is:-0.012588457725833634
# The win percent of longs is: nan
# The win percent of shorts is: -0.0
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: nan
# The biggest losing trade on the short side is: -0.00153304329811479

# %% [markdown]
# XRP
#
# The return when buying short liquidations for 1s is:0.0
# The return when buying short liquidations for 5s is:0.0
# The return when buying short liquidations for 10s is:0.0
# The return when buying short liquidations for 30s is:0.0
# The return when buying short liquidations for 60s is:0.0
# The return when buying short liquidations for 300s is:0.0
# The return when selling long liquidations for 1s is:-0.0008055179009790312
# The return when selling long liquidations for 5s is:-0.0052359672896075795
# The return when selling long liquidations for 10s is:-0.008457916869256557
# The return when selling long liquidations for 30s is:-0.009465148640941898
# The return when selling long liquidations for 60s is:-0.006041647339979054
# The return when selling long liquidations for 300s is:0.034835492968329454
#
# Number of Long Trades:0.0
# Number of Short Trades:-18.0
# Estimated Trading fees for Longs:0.0
# Estimated Trading fees for Shorts:-0.004788000000000001
# The gross return when buying short liquidations for 10s is:0.0
# The net return when buying short liquidations for 10s is:0.0
# The gross return when selling long liquidations for 10s is:-0.008457916869256557
# The net return when selling long liquidations for 10s is:-0.013245916869256557
# The win percent of longs is: nan
# The win percent of shorts is: -0.0
# The biggest winning trade on the long side is: nan
# The biggest losing trade on the long side is: nan
# The biggest winning trade on the short side is: nan
# The biggest losing trade on the short side is: -0.0010069479407914619
